# %%
#| hide
from solveittest.core import *

# %% [markdown]
# # solveittest
#
# > This is just a test repo using solveit.

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install solveittest in Development mode

# %% [markdown]
# ```sh
# # make sure solveittest package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to solveittest
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/Gtombri/solveittest.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c Gtombri solveittest
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install solveittest
# ```
#
#
# [repo]: https://github.com/Gtombri/solveittest
# [docs]: https://Gtombri.github.io/solveittest/
# [pypi]: https://pypi.org/project/solveittest/
# [conda]: https://anaconda.org/Gtombri/solveittest

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/Gtombri/solveittest
# [docs]: https://Gtombri.github.io/solveittest/
# [pypi]: https://pypi.org/project/solveittest/
# [conda]: https://anaconda.org/Gtombri/solveittest

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
